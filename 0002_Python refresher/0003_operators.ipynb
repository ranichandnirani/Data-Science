# %%
a = 10
b = 5

# %%
a + b
# Out:
# 15

# %%
a - b
# Out:
# 5

# %%
a - b
# Out:
# 5

# %%
a * b
# Out:
# 50

# %%
a / b
# Out:
# 2.0

# %%
a // b
# Out:
# 2

# %%
2 ** 2
# Out:
# 4

# %%
a % b
# Out:
# 0

# %%
a = 45

# %%
b = 4

# %%
a > b
# Out:
# True

# %%
a < b
# Out:
# False

# %%
a >= b
# Out:
# True

# %%
a <= b
# Out:
# False

# %%
a == b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
a = 5
b = 5

# %%
a >= b
# Out:
# True

# %%
a <= b
# Out:
# True

# %%
a == b
# Out:
# True

# %%
b1 = True
b2 = False

# %%
not(b1)
# Out:
# False

# %%
not(b2)
# Out:
# True

# %%
b1 or b2
# Out:
# True

# %%
b1 and b2
# Out:
# False

# %%
a = 34

# %%
a += 4

# %%
a
# Out:
# 38

# %%
a -= 3

# %%
a
# Out:
# 35
