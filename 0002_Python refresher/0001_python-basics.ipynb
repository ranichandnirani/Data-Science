# %%
a = 5

# %%
b = 6

# %%
a + b
# Out:
# 11

# %%
print("Hello world")
# Out:
# Hello world

# %%
print(type(a))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(type(a))
#
# NameError: name 'a' is not defined

# %%
name = "Jupyter"

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
type(name)
# Out:
# str

# %%
a = "46576"

# %%
b = "234"

# %%
print(a + b)
# Out:
# 46576234

# %%
int(a) + int(b) #Typecasting
# Out:
# 46810
