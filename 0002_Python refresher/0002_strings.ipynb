# %%
name = "Chandni"

# %%
name
# Out:
# 'Chandni'

# %%
name.upper() #string methods
# Out:
# 'CHANDNI'

# %%
name.endswith("ni")
# Out:
# True

# %%
name.endswith("ya")
# Out:
# False

# %%
name.lower()
# Out:
# 'chandni'

# %%
name.count("n")
# Out:
# 2

# %%
len(name) #length
# Out:
# 7

# %%
name[0:5]
# Out:
# 'Chand'

# %%
name[1:-1]
# Out:
# 'handn'
